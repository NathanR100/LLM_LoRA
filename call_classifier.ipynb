# %% [markdown]
# <h1><center>CHTRJP00076622 Take Home</center></h1>

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The marketing department of a telecom company wants to analyze customer service calls where their customers call in to cancel their service. Transcripts are coming in turns where speaking party is identified either as `Agent` and `Caller` (Customer). The customer service department have identified 4 primary reasons for cancellations. These categories are:
#
#
#
# | Reasons               | Definition                                                                         | Sample Sentences                                          |
# | --------------------- | ---------------------------------------------------------------------------------- | --------------------------------------------------------- |
# | Price Too Expensive   | Customer wants to cancel the service, because the price is expensive               | I want to cancel the Internet, because it is way too much |
# | Price Better Offer    | Customer wants to cancel the service as there are better offer from competitors    | Company X was able to give me a better offer              |
# | No Use                | Customer wants to cancel the service as they are not using the service             | I don't watch TV that much                                |
# | Customer Service Issue| Customer wants to cancel the service as they are not happy with customer service   | The representative I have talked was very rude            |
#
# Data Science team wants to develop a model that will classify the call into the category that belongs to.

# %% [markdown]
# ## Instructions

# %% [markdown]
# 1. Read the data and perform the data cleaning if necessary. <br>
#    a. Data is provided in a file `data/transcripts.xlsx` <br>
#    b. Each row is a single call. Transcript is under `Text` folder. Data is unstructured. You need to parse the transcript. <br>
#
# 2. Develop/design a model that can categorize the calls into the categories listed above. Based on the approach you choose, you might be providing a design/diagram as well. <br>
#    a. **We don't expect you to do a full model development or data tagging** You can use pre-trained models or any other method to tackle this task. Alternatively you can provide a diagram to showcase how you would approach the issue in hand.

# %% [markdown]
# ## Output/Deliverables
#
# 1. Provide either one of the followings: <br>
#     a. Model: A running model that performs the above classification task (it can be pre-trained) <br>
#     b. Diagram: Draw a diagram of how model can be designed from start to end. As long as it is clear and lexible you can use any format (PPT, draw.io, Visio, Canvas, etc). Make sure you share the image with submission of PPT or embedded in this notebook. <br>
# 2. A 5 page (max 5) PPT summarizes approach and results.
# 3. Submit this notebook (`call_classifier.ipynb`) with your code. Make sure outputs are saved. You can export your notebook as HTML ([How to export to HTML](https://mljar.com/blog/jupyter-notebook-html/))

# %% [markdown]
# ----

# %% [markdown]
# ----

# %%
# enter your initials below
initials = "MI"

# %%
### YOUR CODE GOES HERE ###
